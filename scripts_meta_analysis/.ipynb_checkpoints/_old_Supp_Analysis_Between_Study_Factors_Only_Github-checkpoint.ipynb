# %%
data = read.csv("../data_meta_analysis/Data_Classifications_v7.csv")

# %%
library(ggplot2)
library(corrplot)

# %%
## remove neural-net
data<-data[!data$Classifier.type=='neural-net',]

# %%
#data$Region<-as.factor(data$Region)
data$PID<-as.factor(data$PID)
data$Info.type<-as.factor(data$Info.type)
data$Smoothing<-as.factor(data$Smoothing)
data$Roi.Search<-as.factor(data$Roi.Search)
data$Classifier.type<-as.factor(data$Classifier.type)
data$Coregistration<-as.factor(data$Coregistration)
data$Pattern.type<-as.factor(data$Pattern.type)
data$Pattern.normalization.type<-as.factor(data$Pattern.normalization.type)

# %%
data$Classifier.type<-relevel(data$Classifier.type,'correlation')

# %%
data<-droplevels(data)

# %%
#data$Num_subs

# %%
levels(data$PID)
levels(data$Info.type)
levels(data$Smoothing)
levels(data$Roi.Search)
levels(data$Classifier.type)
levels(data$Coregistration)
levels(data$Pattern.type)
levels(data$Pattern.normalization.type)
levels(data$Scanner)
# Out:
#  [1] "1"  "2"  "5"  "6"  "7"  "8"  "9"  "10" "11" "12" "13" "16" "18" "20" "21"
# [16] "22" "23" "24" "25" "26" "27" "28" "31" "32" "33" "37" "39" "41" "42" "43"
# [31] "46" "47" "48" "49" "50" "52" "53" "54" "55" "56" "57" "59" "60" "61" "62"
# [46] "63" "64" "65" "66" "67" "68" "69" "70" "71" "72" "73" "74" "75" "76" "77"
# [61] "78" "79" "80" "81" "82" "83" "84" "85" "86" "87" "88" "89" "90" "91" "92"
# [76] "93"
# [1] "Perceptual" "Response"   "Rule"       "Value"
# [1] "smoothed" "unsmooth"
# [1] "ROI"              "Searchlight Peak"
# [1] "correlation" "GNB"         "LDA"         "LogReg"      "svm-lin"
# [6] "svm-nonlin"
# [1] "coregistered" "Native Space"
# [1] "Multi-Trial Multi-Time Point"   "Multi-Trial Single-Time Point"
# [3] "Single Trial Multi-Time Point"  "Single Trial Single-Time Point"
# [1] "None"                  "Normalized Spatially"  "Normalized Temporally"
# [1] "3T" "7T"

# %%
variables = c('Accuracy.50','PID','Info.type','Smoothing','Roi.Search','Classifier.type','Coregistration','Pattern.type','Pattern.normalization.type','Significance','Scanner','Num_subs')

#data[,variables]

# %% [markdown]
# subset to 50% accuracy

# %% [markdown]
# adding significance reduces the dataset.

# %%
data_50<-data[!is.na(data$Accuracy.50),variables]
nrow(data_50)
data_50<-data_50[complete.cases(data_50),]
nrow(data_50)
# Out:
# [1] 877
# [1] 877

# %% [markdown]
# # Models Just Testing Between Subject Designs

# %% [markdown]
# take average of each study.
# - check which studies use more than one method.
# - probably want to do it between region as well.

# %%
data_50_paper = data.frame(Accuracy.50 = numeric(), PID = factor(), Info.type = factor(),Smoothing=factor(),
                           Roi.Search=factor(),Classifier.type=factor(),Coregistration=factor(),Pattern.type=factor(),
                          Pattern.normalization.type=factor(),Significance=factor(),NumSubs=numeric(),Scanner=factor())

# %%
unique(data_50$PID)
# Out:
#  [1] 93 88 87 80 77 75 69 66 64 63 59 57 56 55 53 52 50 43 37 33 32 28 23 16 11
# [26] 10 6  1  91 85 82 78 71 49 48 24 13 5  84 83 79 76 74 73 72 70 67 65 60 54
# [51] 47 46 42 41 31 27 26 25 22 21 20 18 12 9  8  7  2  92 90 89 86 81 68 62 61
# [76] 39
# 76 Levels: 1 2 5 6 7 8 9 10 11 12 13 16 18 20 21 22 23 24 25 26 27 28 31 ... 93

# %%
#head(data_50)

# %%
data_50<-data_50[data_50$Significance==1,]

# %%
for (pi in unique(data_50$PID)){
    d<-data_50[data_50$PID==pi,]
    data_50_paper<-rbind(data_50_paper,data.frame(Accuracy.50 = mean(d$Accuracy.50), PID = pi, Info.type = d$Info.type[1],
                                                 Smoothing=d$Smoothing[1],Roi.Search=d$Roi.Search[1],Classifier.type=d$Classifier.type[1],
                                                  Coregistration=d$Coregistration[1],Pattern.type=d$Pattern.type[1],
                                                  Pattern.normalization.type=d$Pattern.normalization.type[1],
                                                  Significance=d$Significance[1],NumSubs=d$Num_subs[1],Scanner=d$Scanner[1]))

    
}

# %%
data_50_paper<-data_50_paper[order(data_50_paper$PID),]
#head(data_50_paper)
nrow(data_50_paper)
# Out:
# [1] 75

# %%
data_50_paper$PID2<-as.numeric(data_50_paper$PID)
data_50_paper['Classifier']<-data_50_paper$Classifier.type
#levels(data_50_paper$Classifier)<-c('linear svm','correlation','gnb','lda','logistic reg','nonlinear svm')

jpeg('../Figures/Supp/scatter_single_study_classifier.jpg',width=8,height=4,units="in",res=800)
p<-ggplot(aes(y = Accuracy.50, x = PID2,color=Classifier), data = data_50_paper) +geom_point()+xlab('Study')#+facet_wrap('Info.type')
#p<-p+theme(panel.background=element_blank(),axis.ticks.x=element_blank(),axis.text.x=element_blank())
p<-p+theme(panel.background=element_blank())
#p<-p+theme(axis.text.x = element_text(angle = 0, hjust = 1,size=6))
p<-p+theme(axis.line.x = element_line(color="black", size = .3),
        axis.line.y = element_line(color="black", size = .3))

p<-p+ylab('Classification Accuracy')
p<-p+xlab('Study ID')
p

dev.off()
p
options(repr.plot.width=8, repr.plot.height=4)
# Out:
# pdf
#   2
# plot without title

# %%
data_50_paper$Classifier.type<-relevel(data_50_paper$Classifier.type,'svm-lin')
factor_model<-lm(Accuracy.50~Roi.Search+Pattern.type+Classifier.type+
                Smoothing+Coregistration+Pattern.normalization.type+NumSubs+Scanner,data=data_50_paper)
summary(factor_model)
anova(factor_model)

# no info-type - it's not really between study - 10 studies with more than 1 type -
# Out:
# Call:
# lm(formula = Accuracy.50 ~ Roi.Search + Pattern.type + Classifier.type +
#     Smoothing + Coregistration + Pattern.normalization.type +
#     NumSubs + Scanner, data = data_50_paper)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.140504 -0.036107 -0.004194  0.020468  0.226758
#
# Coefficients:
#                                                   Estimate Std. Error t value
# (Intercept)                                      0.6195123  0.0304730  20.330
# Roi.SearchSearchlight Peak                       0.0004285  0.0216562   0.020
# Pattern.typeMulti-Trial Single-Time Point       -0.0359642  0.0307008  -1.171
# Pattern.typeSingle Trial Multi-Time Point       -0.0223188  0.0243298  -0.917
# Pattern.typeSingle Trial Single-Time Point      -0.0152124  0.0270486  -0.562
# Classifier.typecorrelation                       0.1278772  0.0689117   1.856
# Classifier.typeGNB                              -0.0079730  0.0430706  -0.185
# Classifier.typeLDA                               0.0106933  0.0538866   0.198
# Classifier.typeLogReg                           -0.0165215  0.0273134  -0.605
# Classifier.typesvm-nonlin                        0.1467879  0.0378453   3.879
# Smoothingunsmooth                                0.0148461  0.0205444   0.723
# CoregistrationNative Space                      -0.0037965  0.0183046  -0.207
# Pattern.normalization.typeNormalized Spatially  -0.0026905  0.0315266  -0.085
# Pattern.normalization.typeNormalized Temporally -0.0059661  0.0214388  -0.278
# NumSubs                                         -0.0009894  0.0007990  -1.238
# Scanner7T                                        0.0473391  0.0456581   1.037
#                                                 Pr(>|t|)
# (Intercept)                                      < 2e-16 ***
# Roi.SearchSearchlight Peak                      0.984279
# Pattern.typeMulti-Trial Single-Time Point       0.246131
# Pattern.typeSingle Trial Multi-Time Point       0.362696
# Pattern.typeSingle Trial Single-Time Point      0.575968
# Classifier.typecorrelation                      0.068498 .
# Classifier.typeGNB                              0.853773
# Classifier.typeLDA                              0.843382
# Classifier.typeLogReg                           0.547573
# Classifier.typesvm-nonlin                       0.000267 ***
# Smoothingunsmooth                               0.472759
# CoregistrationNative Space                      0.836406
# Pattern.normalization.typeNormalized Spatially  0.932280
# Pattern.normalization.typeNormalized Temporally 0.781766
# NumSubs                                         0.220494
# Scanner7T                                       0.304052
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06452 on 59 degrees of freedom
# Multiple R-squared:  0.357,	Adjusted R-squared:  0.1935
# F-statistic: 2.183 on 15 and 59 DF,  p-value: 0.0173
# Analysis of Variance Table
#
# Response: Accuracy.50
#                            Df   Sum Sq   Mean Sq F value   Pr(>F)
# Roi.Search                  1 0.004058 0.0040580  0.9749 0.327481
# Pattern.type                3 0.029881 0.0099603  2.3930 0.077476 .
# Classifier.type             5 0.086096 0.0172192  4.1370 0.002744 **
# Smoothing                   1 0.002794 0.0027943  0.6713 0.415883
# Coregistration              1 0.000056 0.0000561  0.0135 0.907995
# Pattern.normalization.type  2 0.000223 0.0001113  0.0267 0.973623
# NumSubs                     1 0.008739 0.0087390  2.0996 0.152634
# Scanner                     1 0.004474 0.0044744  1.0750 0.304052
# Residuals                  59 0.245572 0.0041622
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
