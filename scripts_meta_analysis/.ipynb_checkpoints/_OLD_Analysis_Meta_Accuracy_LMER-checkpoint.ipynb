# %%
sessionInfo()
# Out:
# R version 3.2.2 (2015-08-14)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: CentOS release 6.7 (Final)
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# loaded via a namespace (and not attached):
#  [1] magrittr_1.5    IRdisplay_0.3   tools_3.2.2     base64enc_0.1-3
#  [5] uuid_0.1-2      stringi_1.0-1   rzmq_0.7.7      IRkernel_0.5
#  [9] jsonlite_0.9.17 stringr_1.0.0   digest_0.6.8    repr_0.3
# [13] evaluate_0.8

# %%
.libPaths("your/path")

# %%
library(ggplot2)
library(nlme) # load the nlme package.
library(MASS)
#library(effects)
#library(car)
#library(GGally)
library(lme4)
# Out:
# Loading required package: Matrix
#
# Attaching package: ‘lme4’
#
# The following object is masked from ‘package:nlme’:
#
#     lmList

# %%
datadir = '../Data'
data = read.csv(paste(datadir,"Data_Classifications_v3.csv",sep='/'))
datapapers = read.csv(paste(datadir,"Data_Papers_v2.csv",sep='/'))

drops<-names(data)[grep("AAL",names(data))]
data<-data[,!(names(data) %in% drops)]
drops<-names(data)[grep("Notes",names(data))]
data<-data[,!(names(data) %in% drops)]
drops<-names(data)[grep("Coordinate",names(data))]
data<-data[,!(names(data) %in% drops)]
#drops<-names(data)[grep("Region.Label",names(data))]
#data<-data[,!(names(data) %in% drops)]
idx = !is.na(data$PID)
data<-data[idx,]

data$PID = as.factor(data$PID) # make sure paper ID is factor not numeric



data<-data[!is.na(data$Accuracy.50),]

data<-data[data$Roi.Search=='ROI',]

# %%
length(data$Accuracy.50)
# Out:
# [1] 598

# %%
fit1<-lmer(data$Accuracy.50 ~ 1 + (1|data$PID))
summary(fit1)
# Out:
# Linear mixed model fit by REML ['lmerMod']
# Formula: data$Accuracy.50 ~ 1 + (1 | data$PID)
#
# REML criterion at convergence: -1504.7
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.7254 -0.4942 -0.0696  0.3697  5.2400
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  data$PID (Intercept) 0.003703 0.06086
#  Residual             0.004099 0.06403
# Number of obs: 598, groups:  data$PID, 35
#
# Fixed effects:
#             Estimate Std. Error t value
# (Intercept)  0.58732    0.01124   52.27

# %%
coef(fit1)
# Out:
# $`data$PID`
#    (Intercept)
# 1    0.5358328
# 2    0.5913777
# 5    0.5439851
# 7    0.5351836
# 8    0.5819734
# 10   0.5843058
# 11   0.5434804
# 12   0.5873303
# 13   0.5263283
# 16   0.5826762
# 18   0.6074070
# 22   0.5522790
# 23   0.5516388
# 25   0.5743542
# 28   0.5516388
# 31   0.6676372
# 32   0.5365500
# 33   0.5643870
# 37   0.5316959
# 41   0.6404313
# 43   0.5721054
# 46   0.6038501
# 47   0.5544059
# 48   0.5945006
# 49   0.5472642
# 53   0.5590852
# 54   0.7110242
# 55   0.5827807
# 57   0.5583681
# 60   0.6008395
# 61   0.6455484
# 63   0.5826086
# 65   0.5825475
# 66   0.7851671
# 69   0.6856806
#
# attr(,"class")
# [1] "coef.mer"

# %%
VarCorr(fit1)
# Out:
#  Groups   Name        Std.Dev.
#  data$PID (Intercept) 0.060856
#  Residual             0.064026

# %%
#install.packages("arm", repos='http://cran.rstudio.com/')

# %%
library(sjPlot)

# %%
sjp.lmer(fit1,'re')
# Out:
# Plotting random effects...
# plot without title
