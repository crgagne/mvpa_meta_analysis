# %%
data = read.csv("../data_meta_analysis/Data_Classifications_v7.csv")
length(unique(data$PID))
# Out:
# [1] 76

# %%
PID=12

# %%
data<-data[data$Significance==1,]

# %%
for (PID in unique(data$PID)){
    data[data$PID==PID,'num_analyses']<-nrow(data[data$PID==PID,])
    data[data$PID==PID,'has_rule']<-is.element('Rule',data[data$PID==PID,'Info.type'])
    data[data$PID==PID,'study_acc']<-round(mean(data[data$PID==PID,'Accuracy.50']),3)
    
}

# %%
d<-data[!duplicated(data$PID),c('PID','Title','Num_subs','num_analyses','has_rule','study_acc')]
d<-d[order(d$PID),]
d[40:80,]
# Out:
#      PID
# 618  56
# 622  57
# 631  59
# 632  60
# 638  61
# 639  62
# 640  63
# 646  64
# 648  65
# 653  66
# 659  67
# 660  68
# 663  69
# 690  71
# 694  72
# 695  73
# 696  74
# 703  75
# 707  76
# 712  77
# 714  78
# 746  79
# 757  80
# 765  81
# 781  82
# 787  83
# 797  84
# 799  85
# 804  86
# 820  87
# 834  88
# 840  89
# 845  90
# 847  91
# 851  92
# 859  93
# NA   NA
# NA.1 NA
# NA.2 NA
# NA.3 NA
# NA.4 NA
#      Title
# 618  Evaluative vs. trait representation in intergroup social judgments: Distinctroles of anterior temporal lobe and prefrontal cortex
# 622  Dissociable Neural Mechanisms for Goal-Directed Versus Incidental Memory Reactivation
# 631  Investigation of melodic contour processing in the brain using multivariate pattern-based fMRI
# 632  _Decoding the neural substrates of reward-related decision making with functional MRI
# 638  Prediction of Subjective Affective State From Brain Activations
# 639  Appearance Matters: Neural Correlates of Food Choice and Packaging Aesthetics
# 640  Spatial relations and spatial locations are dissociated within prefrontal and parietal cortex
# 646  Within- and cross-participant classifiers reveal different neural coding of information
# 648  Feature-Specific Attentional Priority Signals in HumanCortex
# 653  Representation of Spatial Information in Key Areas of theDescending Pain Modulatory System
# 659  Predicting free choices for abstract intentions
# 660  Interpersonal Liking modulates motor related regions
# 663  Judging semantic similarity: an event-related fMRI study with auditory word stimuli
# 690  The involvement of the fronto-parietal brain network in oculomotor sequence learning using fMRI
# 694  Multiple neural representations of elementary logical connectives
# 695  Awake, Offline Processing during Associative Learning
# 696  Similar coding of freely chosen and externally cued intentions in a fronto-parietal network
# 703  A Brain System for Auditory Working Memory
# 707  Neural Coding for Instruction-Based Task Sets in Human Frontoparietal and Visual Cortex
# 712  Neural representation of object-specific attentional priority.
# 714  Probing the reaching-grasping network in humans throughmultivoxel patt ern decoding
# 746  Decoding the view expectation during learned maze navigation from human fronto-parietal network
# 757  Attention enhances multi-voxel representation of novel objects in frontal, parietal and visual cortices
# 765  Neural Representation of EmotionRegulation Goals
# 781  Stable Task Representations under Attentional Load Revealed with Multivariate Pattern Analysis of Human Brain Activity
# 787  Reward Motivation Enhances Task Coding in Frontoparietal Cortex
# 797  Flexible Coding of Task Rules in Frontoparietal Cortex: An Adaptive System for Flexible Cognitive Control
# 799  Dopamine D2-Receptor Blockade Enhances Decoding of Prefrontal Signals in Humans
# 804  The Behavioral Relevance of Task Information in Human Prefrontal Cortex
# 820  Characterizing the Associative Content of Brain Structures Involved in Habitual and Goal-Directed Actions in Humans: A Multivariate fMRI Study
# 834  Discrimination of Visual Categories Based on Behavioral Relevance in Widespread Regions of Frontoparietal Cortex
# 840  Cross-Modal Decoding of Neural Patterns Associated with Working Memory: Evidence for Attention-Based Accounts of Working Memory
# 845  The Neural Representation of Voluntary Task-Set Selection in Dynamic Environments
# 847  Differentiating Intended Sensory Outcome from Underlying Motor Actions in the Human Brain
# 851  Classifying the wandering mind: Revealing the affective content of thoughts during task-free rest periods
# 859  A Common Neural Code for Perceived and Inferred Emotion
# NA   NA
# NA.1 NA
# NA.2 NA
# NA.3 NA
# NA.4 NA
#      Num_subs num_analyses has_rule study_acc
# 618  20        2           FALSE    0.535
# 622  26        9            TRUE    0.563
# 631  12        1           FALSE    0.525
# 632  18        6            TRUE    0.603
# 638  18        1           FALSE    0.710
# 639  20        1           FALSE    0.600
# 640  26        6            TRUE    0.573
# 646  20        1           FALSE    0.616
# 648   6        5            TRUE    0.586
# 653  15        6           FALSE    0.822
# 659  34        1            TRUE    0.595
# 660  19        1           FALSE    0.585
# 663  15        7           FALSE    0.741
# 690  13        4           FALSE    0.785
# 694  35        1            TRUE    0.560
# 695  41        1            TRUE    0.520
# 696  35        6            TRUE    0.560
# 703  17        1           FALSE    0.540
# 707  27        5            TRUE    0.572
# 712  13        2           FALSE    0.600
# 714  19       12           FALSE    0.646
# 746   8        2            TRUE    0.545
# 757  38        3           FALSE    0.553
# 765  66       10           FALSE    0.583
# 781   8        2           FALSE    0.545
# 787  24        6            TRUE    0.602
# 797  22        2            TRUE    0.600
# 799  53        4           FALSE    0.605
# 804  21       15           FALSE    0.599
# 820  19        5           FALSE    0.517
# 834  19        3           FALSE    0.530
# 840  21        5           FALSE    0.544
# 845  19        2           FALSE    0.624
# 847  10        4           FALSE    0.622
# 851  30        7           FALSE    0.611
# 859  21       19           FALSE    0.536
# NA   NA       NA              NA       NA
# NA.1 NA       NA              NA       NA
# NA.2 NA       NA              NA       NA
# NA.3 NA       NA              NA       NA
# NA.4 NA       NA              NA       NA

# %%
sum(d$has_rule)
# Out:
# [1] 36
