# %%
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# load data

# %%
## Figure 2

# %%
df = pd.read_csv('feature_mixed_effects_all.csv',index_col=None)
df
# Out:
#                                          Unnamed: 0      coef        se  \
# 0                                 Info.typeResponse  0.004227  0.011144
# 1                                     Info.typeRule  0.003303  0.012279
# 2                                    Info.typeValue  0.039394  0.015455
# 3                                 RegionFrontal_Inf -0.010295  0.011076
# 4                             RegionFrontal_Med.ACC -0.003406  0.010815
# 5                                 RegionFrontal_Mid -0.004478  0.011149
# 6                                 RegionFrontal_Orb -0.011452  0.012974
# 7                                 RegionFrontal_Sup -0.006455  0.012505
# 8                                      RegionInsula -0.015781  0.012036
# 9                                 RegionPostcentral -0.004049  0.018809
# 10                                 RegionPrecentral -0.001288  0.011128
# 11                            RegionSupp_Motor_Area  0.002370  0.012679
# ...

# %%
a = df.name.as_matrix()
aa = [s for s in a if "Info" in s]
aa
# Out:
#   File "<ipython-input-26-b5cfc1594c3e>", line 2
#     aa = [s for s in a if "Info" in s else s]
#                                          ^
# SyntaxError: invalid syntax

# %%
df.loc[df.name==aa,].coef
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-7724b513f2e8> in <module>()
# ----> 1 df.loc[df.name==aa,].coef
#
# /home/bishop/cgagne/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other, axis)
#     724                 other = np.asarray(other)
#     725
# --> 726             res = na_op(values, other)
#     727             if isscalar(res):
#     728                 raise TypeError('Could not compare %s type with Series'
#
# /home/bishop/cgagne/anaconda2/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     642             if isinstance(y, (np.ndarray, pd.Series)):
#     643                 if not is_object_dtype(y.dtype):
# --> 644                     result = lib.vec_compare(x, y.astype(np.object_), op)
#     645                 else:
#     646                     result = lib.vec_compare(x, y, op)
#
# ...

# %%
fig = plt.figure(figsize=(12,12))


gs = gridspec.GridSpec(4, 2)
ax1 = plt.subplot(gs[0:2, 0:2])
ax2 = plt.subplot(gs[2:4, 2:4])

#ax1.errorbar(np.arange(5), np.ones(5), yerr=np.ones(5), fmt='o')

plt.show()
