# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os.path
# %matplotlib inline
from sklearn.neighbors import KernelDensity
from scipy.stats import gaussian_kde
import scipy.stats as stats
import statsmodels as sm

# %% [markdown]
# # Data Load In

# %%
import Scripts_SigNonSig
reload(Scripts_SigNonSig)
from Scripts_SigNonSig import *

# %%
out = get_data_for_sig_nonsig_analyses(average_within_region=True)
# Out:
# Scripts_SigNonSig.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   region_data_single_row['Accuracy.50'] = np.mean(region_data['Accuracy.50'])
# Scripts_SigNonSig.py:158: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   uni_sig = df_50_sig['PID'].unique()
# Scripts_SigNonSig.py:166: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   uni_nonsig = df_50_nonsig['PID'].unique()

# %% [markdown]
# # Simple Within Region (Single AAL Regions)

# %%
df_50_nonsig = out['df_50_nonsig']
df_50_sig = out['df_50_sig']
data_simple_one_region = out['data_simple_one_region']
R1 = out['R1']
data_simple_one_region_average_within_region_sig = out['data_simple_one_region_average_within_region_sig']

# %%
#%matplotlib qt
# %matplotlib inline
plt.figure(figsize=(12,8))
df = df_50_sig
for pid in df.PID.unique(): 
    accs = df.loc[df['PID']==pid,'Accuracy.50']
    plt.scatter(np.ones(len(accs))*pid,accs)
    
df = data_simple_one_region_average_within_region_sig
for pid in df.PID.unique(): 
    accs = df.loc[df['PID']==pid,'Accuracy.50']
    plt.scatter(np.ones(len(accs))*pid+.2,accs,color='red')

# %% [markdown]
# # Within Region (Single AAL Regions)

# %%
data_average_within_region_sig = out['data_average_within_region_sig']

# %%
#%matplotlib qt
# %matplotlib inline
plt.figure(figsize=(12,6))
df = df_50_sig
for pid in df.PID.unique(): 
    accs = df.loc[df['PID']==pid,'Accuracy.50']
    plt.scatter(np.ones(len(accs))*pid,accs)
    
df = data_average_within_region_sig
for pid in df.PID.unique(): 
    accs = df.loc[df['PID']==pid,'Accuracy.50']
    plt.scatter(np.ones(len(accs))*pid+.2,accs,color='red')
    
plt.ylabel('Accuracy')
plt.xlabel('Study ID')
plt.title('averaging accuracy within each unique ROI in a study (significant)')
plt.savefig('../Figures/Supp/scatter_averaging_within_all_regions_sig.png')

# %%
len(data_average_within_region_sig)
len(df_50_sig)
# Out:
# 506

# %%
data_average_within_region_nonsig = out['data_average_within_region_nonsig']

# %%
#%matplotlib qt
# %matplotlib inline
plt.figure(figsize=(12,6))
df = df_50_nonsig
for pid in df.PID.unique(): 
    accs = df.loc[df['PID']==pid,'Accuracy.50']
    plt.scatter(np.ones(len(accs))*pid,accs,color='green')
    
df = data_average_within_region_nonsig
for pid in df.PID.unique(): 
    accs = df.loc[df['PID']==pid,'Accuracy.50']
    plt.scatter(np.ones(len(accs))*pid+.2,accs,color='red')
plt.ylabel('Accuracy')
plt.xlabel('Study ID')
plt.title('averaging accuracy within each unique ROI in a study (not-significant)')
plt.savefig('../Figures/Supp/scatter_averaging_within_all_regions_nonsig.png')
